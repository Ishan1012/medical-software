# %% [markdown]
# # Univariate Analysis for Exploratory Data Analysis of Healthcare Datasets
#
# - Univariate data involves observations consisting of only one variable.
# - The goal is to describe and summarize this single variable’s properties such as its average, spread and shape of distribution.
# - Through this exploratory data analysis, we want to preform Univariate Analysis of different variables present in different datasets.

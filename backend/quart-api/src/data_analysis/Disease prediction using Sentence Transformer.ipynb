# %% [markdown]
# # **Disease Prediction** using **Sentence Transformer**

# %% [markdown]
# We are going to use following datasets:
# - Original_Dataset.csv
# - Doctor_Specialist.csv
# - Doctor_Versus_Disease.csv
# - Symptom_Weights.csv
# - Specialist.xlsx

# %%
# !pip install sentence-transformers
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# ...

# %%
disease_vs_symptoms_df = pd.read_csv('datasets/Original_Dataset.csv')
doctor_specialist_df = pd.read_csv('datasets/Doctor_Specialist.csv')
doctor_versus_disease_df = pd.read_csv('datasets/Doctor_Versus_Disease.csv', header=None, index_col=None, encoding='ISO-8859-1')
symptom_weights_df = pd.read_csv('datasets/Symptom_Weights.csv', header=None, index_col=None)
specialist_df = pd.read_excel('datasets/Specialist.xlsx')

# %%
disease_vs_symptoms_df.head()
# Out:
#             Disease  Symptom_1             Symptom_2             Symptom_3  \
# 0  Fungal infection    itching             skin_rash  nodal_skin_eruptions
# 1  Fungal infection  skin_rash  nodal_skin_eruptions   dischromic _patches
# 2  Fungal infection    itching  nodal_skin_eruptions   dischromic _patches
# 3  Fungal infection    itching             skin_rash   dischromic _patches
# 4  Fungal infection    itching             skin_rash  nodal_skin_eruptions
#
#              Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0  dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                  NaN       NaN       NaN       NaN       NaN       NaN
# 2                  NaN       NaN       NaN       NaN       NaN       NaN
# 3                  NaN       NaN       NaN       NaN       NaN       NaN
# 4                  NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# ...

# %%
symptoms = disease_vs_symptoms_df.iloc[:,1:]
symptoms_str = disease_vs_symptoms_df.iloc[:,1:].apply(lambda row: ','.join(row.dropna().astype(str)), axis=1).str.replace('_', ' ')
symptoms_str
# Out:
# 0       itching,skin rash,nodal skin eruptions,dischro...
# 1       skin rash,nodal skin eruptions,dischromic  pat...
# 2        itching,nodal skin eruptions,dischromic  patches
# 3                   itching,skin rash,dischromic  patches
# 4                  itching,skin rash,nodal skin eruptions
#                               ...
# 4915    vomiting,headache,nausea,spinning movements,lo...
# 4916     skin rash,pus filled pimples,blackheads,scurring
# 4917    burning micturition,bladder discomfort,foul sm...
# 4918    skin rash,joint pain,skin peeling,silver like ...
# 4919    skin rash,high fever,blister,red sore around n...
# Length: 4920, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'symptom_columns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 60
#      56                 break
# ...
